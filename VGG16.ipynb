# %%
from keras.applications.vgg16 import VGG16
model=VGG16()

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
import numpy as np

# %%
# path='/content/drive/MyDrive/Datasets/phone.jpg'
path='/content/drive/MyDrive/Datasets/lighter.jpg'
image= load_img(path,target_size=(224,224))
image=img_to_array(image)

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
image=image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))
image.shape
# Out:
# (1, 224, 224, 3)

# %%
# !pip install opencv-python

# %%
image=preprocess_input(image)
image
# Out:
# array([[[[-103.939     ,  -94.779     ,  -80.68      ],
#          [-102.939     ,  -95.779     ,  -80.68      ],
#          [-102.939     ,  -95.779     ,  -80.68      ],
#          ...,
#          [-102.939     ,  -97.779     ,  -82.68      ],
#          [-102.939     ,  -97.779     ,  -82.68      ],
#          [-102.939     ,  -97.779     ,  -84.68      ]],
#
#         [[-103.939     ,  -94.779     ,  -80.68      ],
#          [-102.939     ,  -95.779     ,  -80.68      ],
#          [-102.939     ,  -95.779     ,  -80.68      ],
#          ...,
#          [-102.939     ,  -97.779     ,  -82.68      ],
#          [-102.939     ,  -97.779     ,  -82.68      ],
#          [-102.939     ,  -97.779     ,  -84.68      ]],
#
#         [[-102.939     ,  -95.779     ,  -80.68      ],
#          [-100.939     ,  -95.779     ,  -80.68      ],
#          [-102.939     ,  -95.779     ,  -80.68      ],
#          ...,
#          [-102.939     ,  -97.779     ,  -82.68      ],
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(path) #Replace "image.jpg" with the path of your image
plt.imshow(img)

# %%
yhat=model.predict(image)
# yhat
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step

# %%
label=decode_predictions(yhat)
label
# Out:
# [[('n03666591', 'lighter', 0.99987936),
#   ('n02948072', 'candle', 5.4978234e-05),
#   ('n03729826', 'matchstick', 5.205066e-05),
#   ('n04456115', 'torch', 1.0388026e-05),
#   ('n03676483', 'lipstick', 6.4878924e-07)]]

# %%
# label = label[0][0]
# print the classification
# print('%s (%.2f%%)' % (label[1], label[2]*100))
print("Object=",label[0][1],"\npercentage=",label[0][2])
len(label)
# Out:
# Object= 0
# percentage= 3
# 3
